# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# Hollywood    20
# Bollywood    17
# Name: industry, dtype: int64

# %%
df['language'].value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Kannada     1
# Bengali     1
# Name: language, dtype: int64

# %% [markdown]
# <b><i><u>Column Filtering</b>

# %%
df_new = df[['title','imdb_rating','industry']]

# %%
df[['language','industry']].value_counts()
df_new
# Out:
#                                           title  imdb_rating   industry
# 0                               Pather Panchali          8.3  Bollywood
# 1   Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                         Thor: The Dark World           6.8  Hollywood
# 3                               Thor: Ragnarok           7.9  Hollywood
# 4                       Thor: Love and Thunder           6.8  Hollywood
# 5                      The Shawshank Redemption          9.3  Hollywood
# 6                                  Interstellar          8.6  Hollywood
# 7                      The Pursuit of Happyness          8.0  Hollywood
# 8                                     Gladiator          8.5  Hollywood
# 9                                       Titanic          7.9  Hollywood
# 10                        It's a Wonderful Life          8.6  Hollywood
# 11                                       Avatar          7.8  Hollywood
# ...

# %%
df[['industry','language']].value_counts()
# Out:
# industry   language
# Hollywood  English     20
# Bollywood  Hindi       12
#            Telugu       3
#            Kannada      1
#            Bengali      1
# dtype: int64

# %% [markdown]
# <b><i><u>Row Filtering</b>

# %%
df[(df.release_year >= 2000) & (df.release_year <= 2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
df.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
df[df.studio == 'Marvel Studios']
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %% [markdown]
# <i><u>Pandas DataFrame filtering multiple conditions:</i><br>https://stackoverflow.com/questions/13611065/efficient-way-to-apply-multiple-filters-to-pandas-dataframe-or-series

# %% [markdown]
# <b>#<i><u> Quick statistics in DataFrames</b>

# %% [markdown]
# ##### <b>1. df.describe()</b>

# %% [markdown]
# <i>It shows quick statistics for all numeric columns </i>

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %% [markdown]
# ##### <b>2. df.info()</b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.imdb_rating.max()
# Out:
# 9.3

# %%
df[df.imdb_rating == df.imdb_rating.max()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df[df.imdb_rating == df.imdb_rating.min()]
# Out:
#      title   industry  release_year  imdb_rating             studio  budget  \
# 31  Race 3  Bollywood          2018          1.9  Salman Khan Films     1.8
#
#     revenue      unit currency language
# 31      3.1  Billions      INR    Hindi

# %%
df[(df.imdb_rating == df.imdb_rating.max()) | (df.imdb_rating == df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %% [markdown]
# <b>#<i><u> To generate new columns</b>

# %%
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# 3      USD  English

# %% [markdown]
# <i>to add a new column having age of the movie based on one existing column</i>

# %%
df["age"] = df["release_year"].apply(lambda x : 2024 - x)
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age
# 0      INR  Bengali   69
# 1      USD  English    2
# 2      USD  English   11
# 3      USD  English    7

# %% [markdown]
# <i>to add a new column based on two existing columns</i>

# %%
df["profit"] = df.apply(lambda x : x['revenue'] - x['budget'], axis = 1)
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   69  30000.0
# 1      USD  English    2    754.8
# 2      USD  English   11    479.8
# 3      USD  English    7    674.0

# %% [markdown]
# <b>#<i><u> Index Operations</b>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %% [markdown]
# <i><u>we can also set any column as an index<u></i>

# %%
df.set_index("title", inplace = True)
df.head(3)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# ...

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.loc[["K.G.F: Chapter 2","The Kashmir Files"]]
# Out:
#                     industry  release_year  imdb_rating         studio  \
# title
# K.G.F: Chapter 2   Bollywood          2022          8.4  Hombale Films
# The Kashmir Files  Bollywood          2022          8.3    Zee Studios
#
#                    budget  revenue      unit currency language  age  profit
# title
# K.G.F: Chapter 2      1.0     12.5  Billions      INR  Kannada    2    11.5
# The Kashmir Files   250.0   3409.0  Millions      INR    Hindi    2  3159.0

# %%
df.iloc[25]
# Out:
# index                         25
# title           Taare Zameen Par
# industry               Bollywood
# release_year                2007
# imdb_rating                  8.3
# studio                       NaN
# budget                       120
# revenue                     1350
# unit                    Millions
# currency                     INR
# language                   Hindi
# age                           17
# profit                      1230
# Name: 25, dtype: object

# %%
df.iloc[25:28]
# Out:
#                       industry  release_year  imdb_rating  \
# title
# Taare Zameen Par     Bollywood          2007          8.3
# Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# PK                   Bollywood          2014          8.1
#
#                                        studio  budget  revenue      unit  \
# title
# Taare Zameen Par                          NaN   120.0   1350.0  Millions
# Munna Bhai M.B.B.S.  Vinod Chopra Productions   100.0    410.0  Millions
# PK                         Vinod Chopra Films   850.0   8540.0  Millions
#
#                     currency language  age  profit
# title
# Taare Zameen Par         INR    Hindi   17  1230.0
# Munna Bhai M.B.B.S.      INR    Hindi   21   310.0
# PK                       INR    Hindi   10  7690.0

# %%
df.reset_index(inplace = True)
df.head(4)
# Out:
#    index                                        title   industry  \
# 0      0                              Pather Panchali  Bollywood
# 1      1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2      2                        Thor: The Dark World   Hollywood
# 3      3                              Thor: Ragnarok   Hollywood
#
#    release_year  imdb_rating                     studio   budget   revenue  \
# 0          1955          8.3  Government of West Bengal  70000.0  100000.0
# 1          2022          7.0             Marvel Studios    200.0     954.8
# 2          2013          6.8             Marvel Studios    165.0     644.8
# 3          2017          7.9             Marvel Studios    180.0     854.0
#
#         unit currency language  age   profit
# 0  Thousands      INR  Bengali   69  30000.0
# 1   Millions      USD  English    2    754.8
# 2   Millions      USD  English   11    479.8
# 3   Millions      USD  English    7    674.0

# %%
list(df.iloc[24:30].title)
# Out:
# ['Bajirao Mastani ',
#  'Taare Zameen Par',
#  'Munna Bhai M.B.B.S.',
#  'PK',
#  'Sanju',
#  'The Kashmir Files']

# %%
df1 = df.drop(df[df["industry"] == 'Bollywood'].index)

# %%
df1
# Out:
#     index                                        title   industry  \
# 1       1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       2                        Thor: The Dark World   Hollywood
# 3       3                              Thor: Ragnarok   Hollywood
# 4       4                      Thor: Love and Thunder   Hollywood
# 5       5                     The Shawshank Redemption  Hollywood
# 6       6                                 Interstellar  Hollywood
# 7       7                     The Pursuit of Happyness  Hollywood
# 8       8                                    Gladiator  Hollywood
# 9       9                                      Titanic  Hollywood
# 10     10                        It's a Wonderful Life  Hollywood
# 11     11                                       Avatar  Hollywood
# 12     12                                The Godfather  Hollywood
# 13     13                              The Dark Knight  Hollywood
# ...

# %%
df
# Out:
#     index                                        title   industry  \
# 0       0                              Pather Panchali  Bollywood
# 1       1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       2                        Thor: The Dark World   Hollywood
# 3       3                              Thor: Ragnarok   Hollywood
# 4       4                      Thor: Love and Thunder   Hollywood
# 5       5                     The Shawshank Redemption  Hollywood
# 6       6                                 Interstellar  Hollywood
# 7       7                     The Pursuit of Happyness  Hollywood
# 8       8                                    Gladiator  Hollywood
# 9       9                                      Titanic  Hollywood
# 10     10                        It's a Wonderful Life  Hollywood
# 11     11                                       Avatar  Hollywood
# 12     12                                The Godfather  Hollywood
# ...

# %%
df.shape[1]
# Out:
# 13

# %%
df.shape
# Out:
# (37, 13)

# %%
list(df.columns)
# Out:
# ['index',
#  'title',
#  'industry',
#  'release_year',
#  'imdb_rating',
#  'studio',
#  'budget',
#  'revenue',
#  'unit',
#  'currency',
#  'language',
#  'age',
#  'profit']

# %%
grades = pd.DataFrame([['Raj',-15,'A'],['Renuka',19,'B'],['Ragini',25,'D'],['Renuka',-20,'A'],['Raj',15,'A']])
grades.columns = ['Name','Age','Grade']

# %%
grades
# Out:
#      Name  Age Grade
# 0     Raj  -15     A
# 1  Renuka   19     B
# 2  Ragini   25     D
# 3  Renuka  -20     A
# 4     Raj   15     A

# %%
grades.drop_duplicates(subset = list(df.columns), keep = 'last', inplace = False)
# Out:
#      Name  Age Grade
# 1  Renuka   19     B
# 2  Ragini   25     D
# 3  Renuka   20     A
# 4     Raj   15     A

# %%
grades
# Out:
#      Name  Age Grade
# 0     Raj   15     A
# 1  Renuka   19     B
# 2  Ragini   25     D
# 3  Renuka   20     A
# 4     Raj   15     A

# %%
grades.Age.add(1).abs()
# Out:
# 0    14
# 1    20
# 2    26
# 3    19
# 4    16
# Name: Age, dtype: int64

# %%
grades.add_prefix('_')
# Out:
#     _Name  _Age _Grade
# 0     Raj   -15      A
# 1  Renuka    19      B
# 2  Ragini    25      D
# 3  Renuka   -20      A
# 4     Raj    15      A

# %%
grades.Age.agg('max')
# Out:
# 25

# %%
i = df[((df.Name == 'Raj') &( df.Age == 15) & (df.Grade == 'A'))].index

# %%
i
# Out:
# Int64Index([0], dtype='int64')

# %%
df.drop(i)
# Out:
#      Name  Age Grade
# 1  Renuka   19     B
# 2  Ragini   25     D

# %%
df.Name
# Out:
# 0       Raj
# 1    Renuka
# 2    Ragini
# Name: Name, dtype: object

# %%
'Renuka' in list(df.Name)
# Out:
# True

# %%
df
# Out:
#      Name  Age Grade
# 0     Raj   15     A
# 1  Renuka   19     B
# 2  Ragini   25     D

# %%
df.shape[0]+1
# Out:
# 38

# %%
import pandas as pd

def dropDuplicateEmails(customers: pd.DataFrame) -> pd.DataFrame:
    customers.drop_duplicates(subset='email', keep='first', inplace=True)
    return customers
